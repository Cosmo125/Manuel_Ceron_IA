# %% [markdown]
# # Ejercicio 1: Conceptos Básicos de Inteligencia Artificial
#
# ## 🎯 Objetivos
# - Evaluar la comprensión de conceptos fundamentales de IA
# - Practicar la identificación de tipos de problemas de IA
# - Reflexionar sobre las implicaciones éticas de la IA
#
# ## 📋 Instrucciones
# 1. Lee cada pregunta cuidadosamente
# 2. Responde en las celdas marcadas con **"TU RESPUESTA:"**
# 3. Para preguntas de código, ejecuta las celdas y verifica los resultados
# 4. Guarda el notebook con tus respuestas completadas
#
# ---

# %% [markdown]
# ## Parte 1: Definiciones y Conceptos (20 puntos)
#
# ### Pregunta 1.1 (5 puntos)
# Define con tus propias palabras qué es la Inteligencia Artificial. Incluye al menos tres características clave.

# %% [markdown]
# **TU RESPUESTA:**
#
# [Escribe tu definición aquí]

# %% [markdown]
# ### Pregunta 1.2 (5 puntos)
# Explica la diferencia entre:
# - IA débil (narrow AI) vs IA fuerte (general AI)
# - Aprendizaje supervisado vs no supervisado

# %% [markdown]
# **TU RESPUESTA:**
#
# **IA débil vs IA fuerte:**
# [Tu explicación aquí]
#
# **Aprendizaje supervisado vs no supervisado:**
# [Tu explicación aquí]

# %% [markdown]
# ### Pregunta 1.3 (10 puntos)
# Menciona y describe brevemente cinco aplicaciones actuales de IA que uses o conozcas en tu vida diaria.

# %% [markdown]
# **TU RESPUESTA:**
#
# 1. [Aplicación 1 y descripción]
# 2. [Aplicación 2 y descripción]
# 3. [Aplicación 3 y descripción]
# 4. [Aplicación 4 y descripción]
# 5. [Aplicación 5 y descripción]

# %% [markdown]
# ## Parte 2: Clasificación de Problemas (30 puntos)
#
# ### Pregunta 2.1 (30 puntos)
# Para cada uno de los siguientes problemas, identifica:
# - Tipo de problema de IA (clasificación, regresión, clustering, etc.)
# - Tipo de aprendizaje (supervisado, no supervisado, por refuerzo)
# - Dominio de aplicación (NLP, Computer Vision, etc.)

# %%
# Ejecuta esta celda para ver los problemas
problemas = [
    "Determinar si un email es spam o no spam",
    "Predecir el precio de una casa basado en sus características",
    "Agrupar clientes según sus patrones de compra",
    "Reconocer objetos en una fotografía",
    "Traducir texto de inglés a español",
    "Enseñar a un robot a caminar",
    "Detectar fraude en transacciones bancarias",
    "Generar música similar a la de un compositor específico"
]

for i, problema in enumerate(problemas, 1):
    print(f"{i}. {problema}")

# %% [markdown]
# **TU RESPUESTA:**
#
# 1. **Determinar si un email es spam o no spam**
#    - Tipo de problema: [Tu respuesta]
#    - Tipo de aprendizaje: [Tu respuesta]
#    - Dominio de aplicación: [Tu respuesta]
#
# 2. **Predecir el precio de una casa basado en sus características**
#    - Tipo de problema: [Tu respuesta]
#    - Tipo de aprendizaje: [Tu respuesta]
#    - Dominio de aplicación: [Tu respuesta]
#
# [Continúa con los demás problemas...]

# %% [markdown]
# ## Parte 3: Análisis de Casos (25 puntos)
#
# ### Pregunta 3.1 (25 puntos)
# Lee el siguiente caso y responde las preguntas:
#
# **Caso:** Una empresa de streaming quiere implementar un sistema de recomendación que sugiera películas a sus usuarios basándose en sus historiales de visualización, calificaciones y datos demográficos.

# %% [markdown]
# **a) ¿Qué tipo de datos necesitaría el sistema? (5 puntos)**
#
# **TU RESPUESTA:**
# [Lista los tipos de datos necesarios]

# %% [markdown]
# **b) ¿Qué algoritmos de IA podrían ser útiles? (10 puntos)**
#
# **TU RESPUESTA:**
# [Menciona al menos 3 algoritmos y explica por qué]

# %% [markdown]
# **c) ¿Qué métricas usarías para evaluar el éxito del sistema? (10 puntos)**
#
# **TU RESPUESTA:**
# [Lista métricas técnicas y de negocio]

# %% [markdown]
# ## Parte 4: Consideraciones Éticas (25 puntos)
#
# ### Pregunta 4.1 (25 puntos)
# Analiza las implicaciones éticas del siguiente escenario:
#
# **Escenario:** Un hospital quiere usar IA para ayudar a diagnosticar enfermedades a partir de imágenes médicas. El sistema ha mostrado una precisión del 95%, superando a muchos médicos especialistas.

# %% [markdown]
# **a) ¿Cuáles son los beneficios potenciales? (8 puntos)**
#
# **TU RESPUESTA:**
# [Lista al menos 4 beneficios]

# %% [markdown]
# **b) ¿Qué riesgos o preocupaciones éticas identificas? (8 puntos)**
#
# **TU RESPUESTA:**
# [Lista al menos 4 riesgos o preocupaciones]

# %% [markdown]
# **c) ¿Qué medidas recomendarías para mitigar estos riesgos? (9 puntos)**
#
# **TU RESPUESTA:**
# [Propón medidas concretas]

# %% [markdown]
# ## Parte 5: Reflexión Personal (Bonus - 10 puntos)
#
# ### Pregunta 5.1 (10 puntos bonus)
# Escribe un párrafo reflexionando sobre:
# - ¿Qué te motivó a estudiar IA?
# - ¿Cuáles son tus expectativas para este curso?
# - ¿En qué área de la IA te gustaría especializarte y por qué?

# %% [markdown]
# **TU REFLEXIÓN:**
#
# [Escribe tu reflexión personal aquí]

# %% [markdown]
# ---
#
# ## 📊 Criterios de Evaluación
#
# | Criterio | Excelente (4) | Bueno (3) | Satisfactorio (2) | Necesita Mejora (1) |
# |----------|---------------|-----------|-------------------|--------------------|
# | **Comprensión conceptual** | Demuestra comprensión profunda | Comprensión sólida | Comprensión básica | Comprensión limitada |
# | **Precisión técnica** | Respuestas técnicamente correctas | Mayormente correctas | Algunas imprecisiones | Varias imprecisiones |
# | **Análisis crítico** | Análisis profundo y reflexivo | Buen análisis | Análisis superficial | Análisis limitado |
# | **Claridad de expresión** | Muy claro y bien estructurado | Claro y organizado | Generalmente claro | Confuso o desorganizado |
#
# **Puntaje Total: ___/100 (+ ___/10 bonus)**
#
# ## 📚 Recursos para Repasar
# - Notebook: `teoria/01_historia_ia.ipynb`
# - Notebook: `teoria/02_tipos_ia.ipynb`
# - Lecturas recomendadas en el README del módulo
#
# ## 📝 Comentarios del Instructor
# [Espacio reservado para feedback]
